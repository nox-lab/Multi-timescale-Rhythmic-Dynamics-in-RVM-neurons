# %% [markdown]
# # Double Exponential ON cell model (withdrawal aligned)

# %% [markdown]
# The models in this notebook will fit to the entirety of the trial activity of the ON cells (pre and post) simultaneously.

# %%
# Autoreloading of modules and files without restarting notebook.
# %reload_ext autoreload
# %autoreload 2

import os
import json
import arviz as az
import numpy as np
from pathlib import Path
from quantities import s
import matplotlib.pyplot as plt
from pymc import model_to_graphviz


from rvm_analysis.utils import combine_datasets_into_data_manager
from rvm_analysis.utils import import_on_off_trials, import_extra_cells
from rvm_analysis.trial_analysis_functions import create_trial_df
from rvm_analysis.bayesian_cell_models import build_double_exponential_on_model, store_model_predictions
from rvm_analysis.bayesian_cell_models import plot_prior_predictive_checks
from rvm_analysis.bayesian_cell_models import calculate_rate_percentages_of_peak,create_X_and_Y_training_data
from rvm_analysis.bayesian_cell_models import sample_model,compute_and_save_log_likelihood,compute_predictions_over_new_data
from rvm_analysis.plotting import plot_predictions_paper
from rvm_analysis.data_loaders import read_dataset_by_protocol



#! Force the backend back to matplotlib inline (after importing viziphant).
# %matplotlib inline
print(plt.get_backend())
# Out:
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# c:\Users\carla\Documents\Cambridge\PhD\Paper_1\Publication_Code\Multi-timescale-Rhythmic-Dynamics-in-RVM-neurons\env\lib\site-packages\holoviews\util\parser.py:152: PyparsingDeprecationWarning: 'nestedExpr' deprecated - use 'nested_expr'
#   plot_options_short = pp.nestedExpr('[',
# c:\Users\carla\Documents\Cambridge\PhD\Paper_1\Publication_Code\Multi-timescale-Rhythmic-Dynamics-in-RVM-neurons\env\lib\site-packages\holoviews\util\parser.py:152: PyparsingDeprecationWarning: 'setResultsName' deprecated - use 'set_results_name'
#   plot_options_short = pp.nestedExpr('[',
# c:\Users\carla\Documents\Cambridge\PhD\Paper_1\Publication_Code\Multi-timescale-Rhythmic-Dynamics-in-RVM-neurons\env\lib\site-packages\pyparsing\util.py:477: PyparsingDeprecationWarning: 'ignoreExpr' argument is deprecated, use 'ignore_expr'
#   return fn(*args, **kwargs)
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='ce6e2caa-8023-49a0-af80-9600b5db85ef'>
#   <div id="bd70c69b-3d13-468a-bf57-eb5c1fb5756f" data-root-id="ce6e2caa-8023-49a0-af80-9600b5db85ef" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"87bab1c4-ee3c-432a-9343-79956fdc52f7":{"version":"3.4.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"ce6e2caa-8023-49a0-af80-9600b5db85ef"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"41295c7b-83a0-4e02-8ee6-46566530ad5e","attributes":{"plot_id":"ce6e2caa-8023-49a0-af80-9600b5db85ef","comm_id":"91cc4586296546a1b0c090d2c9ebe731","client_comm_id":"15548df7ca1c4ae3b15f561ac023dd28"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"87bab1c4-ee3c-432a-9343-79956fdc52f7","roots":{"ce6e2caa-8023-49a0-af80-9600b5db85ef":"bd70c69b-3d13-468a-bf57-eb5c1fb5756f"},"root_ids":["ce6e2caa-8023-49a0-af80-9600b5db85ef"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#
#
#   <img src='...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
# </div>
# module://matplotlib_inline.backend_inline

# %% [markdown]
# ## Import the trial data

# %%
base_path: Path = Path("./models/on_models/18_double_exponential_aggregated_counts/")
model_name ="on_trial_model.nc"
full_path = base_path / model_name
parameter_dictionary = base_path / "param_dict.json"

with open(parameter_dictionary,"r") as f:
    p: dict = json.load(f)


p['PRIORS']['LOG_K_PRE']['MU'] = 4
p['PRIORS']['LOG_K_PRE']['SIGMA'] = 0.1

p['PRIORS']['LOG_BASE_RATE_PRE']['MU'] = 3
p['PRIORS']['LOG_BASE_RATE_PRE']['SIGMA'] = 0.5
p['PRIORS']['LOG_BASE_RATE_POST']['MU'] = 3
p['PRIORS']['LOG_BASE_RATE_POST']['SIGMA'] = 0.5

p['PRIORS']['LOG_K_POST'] = {
'MU': 2.5,
'SIGMA': 1
}

p['PRIORS']['SIGMA_BASE_RATE_POST'] = 1

p
# Out:
# {'POST_EVENT_PERIOD': 100,
#  'PRE_EVENT_PERIOD': -10,
#  'SKIP': 1,
#  'DRAWS': 1000,
#  'TUNE': 1000,
#  'BIN_SIZE': 0.05,
#  'PRIORS': {'T_LOWER': -4,
#   'T_UPPER': 4,
#   'SIGMA_BASE_RATE': 5,
#   'LOG_BASE_RATE_PRE': {'MU': 3, 'SIGMA': 0.5},
#   'LOG_BASE_RATE_POST': {'MU': 3, 'SIGMA': 0.5},
#   'LOG_K_PRE': {'MU': 4, 'SIGMA': 0.1},
#   'LOG_K_POST': {'MU': 2.5, 'SIGMA': 1},
#   'SIGMA_BASE_RATE_POST': 1}}

# %%
def print_raw_priors(p):
    print(p['PRIORS'][''])

# %%
def deprecated_spike_2_imports():
    """
    Data imports, deprecated in favour of importing directly from NWB.
    """
    dm1 = import_on_off_trials()
    dm2 = import_extra_cells()
    dm = combine_datasets_into_data_manager(dm1,dm2)
    return dm

dm = read_dataset_by_protocol(['evoked','ongoing','evoked/ongoing'])
# Out:
# Found 101 blocks from 101 NWB files.
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Mus03_CA3.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Mus23_CA2.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Mus25_CA2.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# LHb_Mus28_CA2.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Bic04_CA3.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Bic05_CA3.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Bic07_CA3.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Bic16_CA2.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Bic20_CA3.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Bic27_CA2.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Bic36_CA2.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Mus06_CA2.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Bic38_CA2.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Bic42_CA3.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Bic49_CA3.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Bic51_CA4.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Bic52_CA4.smrx
# ['paw_withdrawal', 'heat']
# ['flick', 'heat']
# DMHLido20_BL_cut.smrx
# ['paw_withdrawal', 'heat']
# ['flick', 'heat']
# DP_DTT_Bic02_BL_cut.smrx
# ['paw_withdrawal', 'heat']
# ['flick', 'heat']
# HDB_Bic06_BL_cut.smrx
# ['paw_withdrawal', 'heat']
# ['flick', 'heat']
# HDB_Bic11_BL_cut.smrx
# ['paw_withdrawal', 'heat']
# ['flick', 'heat']
# HDB_Mus20_BL_cut.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Mus07_CA2.smrx
# ['paw_withdrawal', 'heat']
# ['flick', 'heat']
# HDB_Mus22_BL_cut.smrx
# ['paw_withdrawal', 'heat']
# ['flick', 'heat']
# HDB_Mus38_BL_cut.smrx
# ['paw_withdrawal', 'heat']
# ['flick', 'heat']
# HDB_Mus55_BL_cut.smrx
# ['paw_withdrawal', 'heat']
# ['flick', 'heat']
# HDB_Mus60_BL_cut.smrx
# ['paw_withdrawal', 'heat']
# ['flick', 'heat']
# HDB_Mus65_BL_cut.smrx
# ['paw_withdrawal', 'heat']
# ['flick', 'heat']
# HDB_Mus67_BL_cut.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# HDB_Bic09_cut_truncated.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# HDB_Bic115_cut_truncated.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# HDB_Bic12_cut_truncated.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# HDB_Bic125_cut_truncated.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Mus09_CA2.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# HDB_Bic42_cut_truncated.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# HDB_Bic43_cut_truncated.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# HDB_Bic47_cut_truncated.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# HDB_Bic48_cut_truncated.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# HDB_Bic51_cut_truncated.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# HDB_Bic56_cut_truncated.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# HDB_Bic57_cut_truncated.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# HDB_Bic58_cut_truncated.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# HDB_Bic62_cut_truncated.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# HDB_Bic67_cut_truncated.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Mus13_CA2.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# HDB_Bic72_cut_truncated.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# HDB_Bic73_cut_truncated.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# HDB_Bic79_cut_truncated.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# HDB_Bic80_cut_truncated.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# Naive 4-16-24 a ON@2390_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# Naive 4-16-24 b ON@2765_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# Naive 4-16-24 c OFF&ON@2935_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# ZS Naive 4-17-24 a ON@1695_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# ZS Naive 4-18-24 #1 ON&OFF@2120_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# ZS Naive 4-22-24a OFF@2465_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# ZS Naive 4-22-24b OFF@2068_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# ZS Naive 4-23-24a ON@2249_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# ZS Naive 4-23-24b OFF&ON@3244_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# ZS Naive 4-24-24a OFF@1665_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Mus14_CA2.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# ZS Naive 4-25-24a ON@2646_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# ZS Naive 4-25-24b OFF@3009_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# ZS Naive 4-29-24a OFF@2839_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# ZS Naive 4-30-24a OFF@2789_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# ZS Naive 4-30-24b ON@2455_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# ZS Naive 5-1-24a OFF@2302_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# ZS Naive 5-1-24b OFF@2540_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# ZS Naive 5-1-24c ON@2934_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# ZS Naive 5-2-24a OFF@2030_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# ZS Naive 5-2-24b OFF@2632_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# CA_ongoing01a_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# CA_ongoing01b_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# CA_ongoing02a_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# CA_ongoing02b_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# CA_ongoing02c_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# CA_ongoing03a_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# CA_ongoing03b_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# CA_ongoing04a_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# CA_ongoing04b_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# CA_ongoing05a_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# CA_ongoing05b_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Mus15_CA2.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# CA_ongoing06a_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# CA_ongoing06b_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# CA_ongoing07a_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# CA_ongoing07b_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# CA_ongoing08a_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# Neutral ongoing 7-17-24 @1165_Pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# Neutral ongoing 7-19-24@2583_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# Neutral ongoing 7-31-24@2940_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# Neutral ongoing 8-1-24@2827_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# Neutral ongoing 8-14-24@1505_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# Neutral ongoing 8-15-24@4020_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# Neutral Ongoing 8-29-24 @2950_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Mus16_CA2.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# Neutral ongoing 8-7-24 #1@2797_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# Neutral ongoing 8-7-24 #2@2984_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# Neutral ongoing 8-8-24@3195_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# Neutral ongoing 9-4-24 @2670_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# Neutral ongoing 9-5-24 neutral@2749_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Mus22_CA2.smrx

# %%
for block in dm.blocks:
    print([sp.file_origin for sp in block.segments[0].spiketrains])
# Out:
# [WindowsPath('LHb_Mus03_CA3.smrx'), WindowsPath('LHb_Mus03_CA3.smrx'), WindowsPath('LHb_Mus03_CA3.smrx')]
# [WindowsPath('LHb_Mus23_CA2.smrx'), WindowsPath('LHb_Mus23_CA2.smrx')]
# [WindowsPath('LHb_Mus25_CA2.smrx'), WindowsPath('LHb_Mus25_CA2.smrx')]
# [WindowsPath('LHb_Mus28_CA2.smrx'), WindowsPath('LHb_Mus28_CA2.smrx')]
# [WindowsPath('LHb_Bic04_CA3.smrx'), WindowsPath('LHb_Bic04_CA3.smrx'), WindowsPath('LHb_Bic04_CA3.smrx')]
# [WindowsPath('LHb_Bic05_CA3.smrx'), WindowsPath('LHb_Bic05_CA3.smrx'), WindowsPath('LHb_Bic05_CA3.smrx')]
# [WindowsPath('LHb_Bic07_CA3.smrx'), WindowsPath('LHb_Bic07_CA3.smrx'), WindowsPath('LHb_Bic07_CA3.smrx')]
# [WindowsPath('LHb_Bic16_CA2.smrx'), WindowsPath('LHb_Bic16_CA2.smrx')]
# [WindowsPath('LHb_Bic20_CA3.smrx'), WindowsPath('LHb_Bic20_CA3.smrx'), WindowsPath('LHb_Bic20_CA3.smrx')]
# [WindowsPath('LHb_Bic27_CA2.smrx'), WindowsPath('LHb_Bic27_CA2.smrx')]
# [WindowsPath('LHb_Bic36_CA2.smrx'), WindowsPath('LHb_Bic36_CA2.smrx')]
# [WindowsPath('LHb_Mus06_CA2.smrx'), WindowsPath('LHb_Mus06_CA2.smrx')]
# [WindowsPath('LHb_Bic38_CA2.smrx'), WindowsPath('LHb_Bic38_CA2.smrx')]
# [WindowsPath('LHb_Bic42_CA3.smrx'), WindowsPath('LHb_Bic42_CA3.smrx'), WindowsPath('LHb_Bic42_CA3.smrx')]
# [WindowsPath('LHb_Bic49_CA3.smrx'), WindowsPath('LHb_Bic49_CA3.smrx'), WindowsPath('LHb_Bic49_CA3.smrx')]
# [WindowsPath('LHb_Bic51_CA4.smrx'), WindowsPath('LHb_Bic51_CA4.smrx'), WindowsPath('LHb_Bic51_CA4.smrx'), WindowsPath('LHb_Bic51_CA4.smrx')]
# [WindowsPath('LHb_Bic52_CA4.smrx'), WindowsPath('LHb_Bic52_CA4.smrx'), WindowsPath('LHb_Bic52_CA4.smrx'), WindowsPath('LHb_Bic52_CA4.smrx')]
# [WindowsPath('DMHLido20_BL_cut.smrx'), WindowsPath('DMHLido20_BL_cut.smrx')]
# [WindowsPath('DP_DTT_Bic02_BL_cut.smrx'), WindowsPath('DP_DTT_Bic02_BL_cut.smrx')]
# [WindowsPath('HDB_Bic06_BL_cut.smrx'), WindowsPath('HDB_Bic06_BL_cut.smrx')]
# [WindowsPath('HDB_Bic11_BL_cut.smrx'), WindowsPath('HDB_Bic11_BL_cut.smrx')]
# [WindowsPath('HDB_Mus20_BL_cut.smrx'), WindowsPath('HDB_Mus20_BL_cut.smrx')]
# [WindowsPath('LHb_Mus07_CA2.smrx'), WindowsPath('LHb_Mus07_CA2.smrx')]
# [WindowsPath('HDB_Mus22_BL_cut.smrx'), WindowsPath('HDB_Mus22_BL_cut.smrx'), WindowsPath('HDB_Mus22_BL_cut.smrx')]
# [WindowsPath('HDB_Mus38_BL_cut.smrx'), WindowsPath('HDB_Mus38_BL_cut.smrx')]
# [WindowsPath('HDB_Mus55_BL_cut.smrx'), WindowsPath('HDB_Mus55_BL_cut.smrx'), WindowsPath('HDB_Mus55_BL_cut.smrx')]
# [WindowsPath('HDB_Mus60_BL_cut.smrx'), WindowsPath('HDB_Mus60_BL_cut.smrx'), WindowsPath('HDB_Mus60_BL_cut.smrx')]
# [WindowsPath('HDB_Mus65_BL_cut.smrx'), WindowsPath('HDB_Mus65_BL_cut.smrx')]
# [WindowsPath('HDB_Mus67_BL_cut.smrx'), WindowsPath('HDB_Mus67_BL_cut.smrx')]
# [WindowsPath('HDB_Bic09_cut_truncated.smrx')]
# [WindowsPath('HDB_Bic115_cut_truncated.smrx')]
# [WindowsPath('HDB_Bic12_cut_truncated.smrx')]
# [WindowsPath('HDB_Bic125_cut_truncated.smrx'), WindowsPath('HDB_Bic125_cut_truncated.smrx')]
# [WindowsPath('LHb_Mus09_CA2.smrx'), WindowsPath('LHb_Mus09_CA2.smrx')]
# [WindowsPath('HDB_Bic42_cut_truncated.smrx')]
# [WindowsPath('HDB_Bic43_cut_truncated.smrx')]
# [WindowsPath('HDB_Bic47_cut_truncated.smrx')]
# [WindowsPath('HDB_Bic48_cut_truncated.smrx')]
# [WindowsPath('HDB_Bic51_cut_truncated.smrx')]
# [WindowsPath('HDB_Bic56_cut_truncated.smrx')]
# [WindowsPath('HDB_Bic57_cut_truncated.smrx')]
# [WindowsPath('HDB_Bic58_cut_truncated.smrx')]
# [WindowsPath('HDB_Bic62_cut_truncated.smrx')]
# [WindowsPath('HDB_Bic67_cut_truncated.smrx')]
# [WindowsPath('LHb_Mus13_CA2.smrx'), WindowsPath('LHb_Mus13_CA2.smrx')]
# [WindowsPath('HDB_Bic72_cut_truncated.smrx'), WindowsPath('HDB_Bic72_cut_truncated.smrx')]
# [WindowsPath('HDB_Bic73_cut_truncated.smrx')]
# [WindowsPath('HDB_Bic79_cut_truncated.smrx')]
# [WindowsPath('HDB_Bic80_cut_truncated.smrx')]
# [WindowsPath('Naive 4-16-24 a ON@2390_cut_pared.smrx')]
# [WindowsPath('Naive 4-16-24 b ON@2765_cut_pared.smrx')]
# [WindowsPath('Naive 4-16-24 c OFF&ON@2935_cut_pared.smrx'), WindowsPath('Naive 4-16-24 c OFF&ON@2935_cut_pared.smrx')]
# [WindowsPath('ZS Naive 4-17-24 a ON@1695_cut_pared.smrx')]
# [WindowsPath('ZS Naive 4-18-24 #1 ON&OFF@2120_cut_pared.smrx'), WindowsPath('ZS Naive 4-18-24 #1 ON&OFF@2120_cut_pared.smrx')]
# [WindowsPath('ZS Naive 4-22-24a OFF@2465_cut_pared.smrx')]
# [WindowsPath('ZS Naive 4-22-24b OFF@2068_cut_pared.smrx')]
# [WindowsPath('ZS Naive 4-23-24a ON@2249_cut_pared.smrx')]
# [WindowsPath('ZS Naive 4-23-24b OFF&ON@3244_cut_pared.smrx')]
# [WindowsPath('ZS Naive 4-24-24a OFF@1665_cut_pared.smrx')]
# [WindowsPath('LHb_Mus14_CA2.smrx'), WindowsPath('LHb_Mus14_CA2.smrx')]
# [WindowsPath('ZS Naive 4-25-24a ON@2646_cut_pared.smrx')]
# [WindowsPath('ZS Naive 4-25-24b OFF@3009_cut_pared.smrx')]
# [WindowsPath('ZS Naive 4-29-24a OFF@2839_cut_pared.smrx'), WindowsPath('ZS Naive 4-29-24a OFF@2839_cut_pared.smrx')]
# [WindowsPath('ZS Naive 4-30-24a OFF@2789_cut_pared.smrx'), WindowsPath('ZS Naive 4-30-24a OFF@2789_cut_pared.smrx')]
# [WindowsPath('ZS Naive 4-30-24b ON@2455_cut_pared.smrx')]
# [WindowsPath('ZS Naive 5-1-24a OFF@2302_cut_pared.smrx')]
# [WindowsPath('ZS Naive 5-1-24b OFF@2540_cut_pared.smrx')]
# [WindowsPath('ZS Naive 5-1-24c ON@2934_cut_pared.smrx')]
# [WindowsPath('ZS Naive 5-2-24a OFF@2030_cut_pared.smrx')]
# [WindowsPath('ZS Naive 5-2-24b OFF@2632_cut_pared.smrx')]
# [WindowsPath('CA_ongoing01a_cut_pared.smrx'), WindowsPath('CA_ongoing01a_cut_pared.smrx'), WindowsPath('CA_ongoing01a_cut_pared.smrx'), WindowsPath('CA_ongoing01a_cut_pared.smrx'), WindowsPath('CA_ongoing01a_cut_pared.smrx')]
# [WindowsPath('CA_ongoing01b_cut_pared.smrx')]
# [WindowsPath('CA_ongoing02a_cut_pared.smrx'), WindowsPath('CA_ongoing02a_cut_pared.smrx')]
# [WindowsPath('CA_ongoing02b_cut_pared.smrx')]
# [WindowsPath('CA_ongoing02c_cut_pared.smrx'), WindowsPath('CA_ongoing02c_cut_pared.smrx')]
# [WindowsPath('CA_ongoing03a_cut_pared.smrx')]
# [WindowsPath('CA_ongoing03b_cut_pared.smrx')]
# [WindowsPath('CA_ongoing04a_cut_pared.smrx')]
# [WindowsPath('CA_ongoing04b_cut_pared.smrx'), WindowsPath('CA_ongoing04b_cut_pared.smrx')]
# [WindowsPath('CA_ongoing05a_cut_pared.smrx')]
# [WindowsPath('CA_ongoing05b_cut_pared.smrx'), WindowsPath('CA_ongoing05b_cut_pared.smrx')]
# [WindowsPath('LHb_Mus15_CA2.smrx'), WindowsPath('LHb_Mus15_CA2.smrx')]
# [WindowsPath('CA_ongoing06a_cut_pared.smrx'), WindowsPath('CA_ongoing06a_cut_pared.smrx')]
# [WindowsPath('CA_ongoing06b_cut_pared.smrx')]
# [WindowsPath('CA_ongoing07a_cut_pared.smrx')]
# [WindowsPath('CA_ongoing07b_cut_pared.smrx')]
# [WindowsPath('CA_ongoing08a_cut_pared.smrx'), WindowsPath('CA_ongoing08a_cut_pared.smrx')]
# [WindowsPath('Neutral ongoing 7-17-24 @1165_Pared.smrx')]
# [WindowsPath('Neutral ongoing 7-19-24@2583_pared.smrx')]
# [WindowsPath('Neutral ongoing 7-31-24@2940_pared.smrx')]
# [WindowsPath('Neutral ongoing 8-1-24@2827_pared.smrx')]
# [WindowsPath('Neutral ongoing 8-14-24@1505_pared.smrx')]
# [WindowsPath('Neutral ongoing 8-15-24@4020_pared.smrx')]
# [WindowsPath('Neutral Ongoing 8-29-24 @2950_pared.smrx')]
# [WindowsPath('LHb_Mus16_CA2.smrx'), WindowsPath('LHb_Mus16_CA2.smrx')]
# [WindowsPath('Neutral ongoing 8-7-24 #1@2797_pared.smrx')]
# [WindowsPath('Neutral ongoing 8-7-24 #2@2984_pared.smrx')]
# [WindowsPath('Neutral ongoing 8-8-24@3195_pared.smrx')]
# [WindowsPath('Neutral ongoing 9-4-24 @2670_pared.smrx')]
# [WindowsPath('Neutral ongoing 9-5-24 neutral@2749_pared.smrx')]
# [WindowsPath('LHb_Mus22_CA2.smrx'), WindowsPath('LHb_Mus22_CA2.smrx')]

# %%
on_flick_list, on_flick_list_by_cell = dm.plot_spikes_around_event("flick",p["PRE_EVENT_PERIOD"] * s,p["POST_EVENT_PERIOD"] * s,
                                                                             cell_type='ON',sorted_by=None,color_by_file=False,
                                                                             save=None,plot=False)

print(len(on_flick_list))
# Out:
# Next event [end,960.6372463999999 s] cuts off window
# Next event [end,960.6323349999999 s] cuts off window
# Next event [end,960.5768977999999 s] cuts off window
# Next event [end,960.5768977999999 s] cuts off window
# Next event [end,961.3760155999998 s] cuts off window
# Next event [end,961.3760155999998 s] cuts off window
# Next event [end,961.3760155999998 s] cuts off window
# Next event [end,960.7673893999998 s] cuts off window
# Next event [end,960.7673893999998 s] cuts off window
# Next event [end,960.7673893999998 s] cuts off window
# Next event [end,962.3898569999999 s] cuts off window
# Next event [end,962.3898569999999 s] cuts off window
# No corresponding flick, missing trains [20, 21, 22], event 4
# No corresponding flick, missing trains [20, 21, 22], event 4
# No corresponding flick, missing trains [20, 21, 22], event 4
# Next event [end,961.8416963999999 s] cuts off window
# Next event [end,964.4771317999998 s] cuts off window
# Next event [end,964.4771317999998 s] cuts off window
# Next event [end,960.6701883999999 s] cuts off window
# Next event [end,960.8069171999999 s] cuts off window
# Next event [end,961.6389431999999 s] cuts off window
# Next event [end,962.4861661999998 s] cuts off window
# Next event [end,962.4861661999998 s] cuts off window
# Next event [end,961.2888323999999 s] cuts off window
# Next event [end,961.2888323999999 s] cuts off window
# Next event [heat,306.67527279999996 s] cuts off window
# Next event [end,962.9015031999999 s] cuts off window
# No corresponding flick, missing trains [96], event 2
# Next event [end,2742.0 s] cuts off window
# Next event [end,3368.0 s] cuts off window
# Next event [end,2588.0 s] cuts off window
# Next event [end,2470.0 s] cuts off window
# Next event [end,2557.0 s] cuts off window
# Next event [end,2557.0 s] cuts off window
# Next event [end,2557.0 s] cuts off window
# Next event [end,2557.0 s] cuts off window
# Next event [end,2115.0 s] cuts off window
# Next event [heat,2022.0655779999997 s] cuts off window
# Next event [end,2098.0 s] cuts off window
# Next event [heat,2022.0655779999997 s] cuts off window
# Next event [end,2098.0 s] cuts off window
# Next event [end,2124.0 s] cuts off window
# Next event [heat,2027.8147343999997 s] cuts off window
# Next event [end,2055.0 s] cuts off window
# Next event [end,2196.0 s] cuts off window
# Next event [end,2196.0 s] cuts off window
# Next event [heat,2097.755569 s] cuts off window
# Next event [heat,2097.755569 s] cuts off window
# Next event [end,961.3856303999999 s] cuts off window
# Next event [end,961.3856303999999 s] cuts off window
# max possible flicks:  241
# Max possible heats:  245
# 195

# %%
df = create_trial_df(p["BIN_SIZE"] * s,on_flick_list_by_cell)
display(df)

# Plot the raw count data
plt.scatter(df['time'],df['count'])
plt.show()

counts = df.groupby('time',as_index=False)['count'].sum()
print(counts)
# Out:
#          index              animal  cell  trial   time  count
# 0            0  LHb_Mus03_CA3.smrx     0      0 -10.00      0
# 1            1  LHb_Mus03_CA3.smrx     0      0  -9.95      0
# 2            2  LHb_Mus03_CA3.smrx     0      0  -9.90      0
# 3            3  LHb_Mus03_CA3.smrx     0      0  -9.85      0
# 4            4  LHb_Mus03_CA3.smrx     0      0  -9.80      0
# ...        ...                 ...   ...    ...    ...    ...
# 428995  428995  LHb_Mus16_CA2.smrx    69      1  99.75      0
# 428996  428996  LHb_Mus16_CA2.smrx    69      1  99.80      0
# 428997  428997  LHb_Mus16_CA2.smrx    69      1  99.85      0
# 428998  428998  LHb_Mus16_CA2.smrx    69      1  99.90      0
# 428999  428999  LHb_Mus16_CA2.smrx    69      1  99.95      0
#
# [429000 rows x 6 columns]
#        time  count
# 0    -10.00     33
# 1     -9.95     26
# 2     -9.90     27
# 3     -9.85     26
# 4     -9.80     31
# ...     ...    ...
# 2195  99.75     56
# 2196  99.80     59
# 2197  99.85     46
# 2198  99.90     62
# 2199  99.95     53
#
# [2200 rows x 2 columns]

# %%
X_data,Y_data = create_X_and_Y_training_data(counts,skip=1,plot=True)

# %% [markdown]
# ## Model definitinon

# %%
from rvm_analysis.bayesian_cell_models import build_double_exponential_on_model_reversed_sampling


on_model = build_double_exponential_on_model(X_data,Y_data,p)

# %% [markdown]
# ## Vizualise the model

# %%
# model_to_graphviz(on_model,save=os.path.join(base_path,"graph.png"))

# %% [markdown]
# ## Prior predictive checks

# %%
X_test = np.linspace(-10,20,500)
plot_prior_predictive_checks(on_model,X_test,n_sample_paths=100)
# Out:
# Sampling: [beta_1_post, beta_1_pre, beta_slow_post, log_base_rate_post, log_base_rate_pre, log_k_post, log_k_pre, t_switch]
# [distfit] >INFO> Sampling: [beta_1_post, beta_1_pre, beta_slow_post, log_base_rate_post, log_base_rate_pre, log_k_post, log_k_pre, t_switch]

# %% [markdown]
# ## Sample from the model

# %% [markdown]
# We sample from the model, and save the results. If the model has already been sampled from, then we generate the derived quantities for use in the plotting and later analysis.

# %%
SAMPLE = True

idata = sample_model(on_model,X_data,full_path,p,sample=SAMPLE,chains=4,
                     target_accept=0.8) # 0.8 is the default
# Out:
# Auto-assigning NUTS sampler...
# [distfit] >INFO> Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# [distfit] >INFO> Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# [distfit] >INFO> Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [t_switch, log_base_rate_pre, log_base_rate_post, beta_1_pre, beta_1_post, beta_slow_post, log_k_pre, log_k_post]
# [distfit] >INFO> NUTS: [t_switch, log_base_rate_pre, log_base_rate_post, beta_1_pre, beta_1_post, beta_slow_post, log_k_pre, log_k_post]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 03:46&lt;00:00 Sampling 4 chains, 14 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 253 seconds.
# [distfit] >INFO> Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 253 seconds.
# There were 14 divergences after tuning. Increase `target_accept` or reparameterize.
# [distfit] >ERROR> There were 14 divergences after tuning. Increase `target_accept` or reparameterize.

# %% [markdown]
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 220 seconds.
# [distfit] >INFO> Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 220 seconds.
# There were 29 divergences after tuning. Increase `target_accept` or reparameterize.
# [distfit] >ERROR> There were 29 divergences after tuning. Increase `target_accept` or reparameterize.

# %%
# # Calculate tau values and exponentiated HDIs
posterior = idata.posterior
derived_params = {
"tau_pre": 1/posterior['beta_1_pre'],
"tau_post_slow": 1/posterior['beta_slow_post'],
"tau_post_fast": 1/posterior['beta_1_post'],

"r_pre": np.exp(posterior['log_base_rate_pre']),
"r_post": np.exp(posterior['log_base_rate_post']),

"k_post": np.exp(posterior['log_k_post']),
"k_pre": np.exp(posterior['log_k_pre']),
"posterior_rate_diff": np.exp(posterior['log_base_rate_pre']) - np.exp(posterior['log_base_rate_post']),
}

idata.posterior = idata.posterior.assign(**derived_params)

# %%
idata
# Out:
# Inference data with groups:
# 	> posterior
# 	> sample_stats
# 	> observed_data
# 	> constant_data

# %%
var_names = ["r_post","r_pre","k_post",
 "k_slow","tau_post_slow","t_switch","k_pre","tau_post_fast","tau_pre","posterior_rate_diff"]

# %% [markdown]
# ## Compute the model log likelihood and save

# %%
COMPUTE_LL = True
loglik_save_path = base_path / "idata_with_log_liks.nc" 

compute_and_save_log_likelihood(on_model,idata,save_path=loglik_save_path,recompute=COMPUTE_LL)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:02&lt;00:00]
#     </div>
# Computed from 4000 posterior samples and 2200 observations log-likelihood matrix.
#
#          Estimate       SE
# elpd_loo -7215.49    20.13
# p_loo        4.44        -
# ------
#
# Pareto k diagnostic values:
#                          Count   Pct.
# (-Inf, 0.5]   (good)     2200  100.0%
#  (0.5, 0.7]   (ok)          0    0.0%
#    (0.7, 1]   (bad)         0    0.0%
#    (1, Inf)   (very bad)    0    0.0%

# %% [markdown]
# ## Summarize the model

# %%
# Print a summary of the model parameters
summary = az.summary(idata,var_names=var_names)

display(summary)

summary.to_latex(os.path.join(base_path,"posterior_table_ON_flick_double_exp.tex"),index=True, escape=True,
                 float_format="%.3f")
# Out:
#                         mean      sd   hdi_3%  hdi_97%  mcse_mean  mcse_sd  \
# r_post                16.002   5.129    6.475   25.429      0.112    0.081
# r_pre                 30.685   0.473   29.822   31.574      0.009    0.006
# k_post                50.007   2.232   45.764   54.248      0.054    0.039
# k_slow                64.386   4.881   54.621   72.667      0.104    0.074
# tau_post_slow        164.223  18.883  129.571  199.809      0.417    0.295
# t_switch              -0.184   0.039   -0.257   -0.108      0.001    0.001
# k_pre                 99.711   2.318   95.487  104.250      0.058    0.041
# tau_post_fast          4.157   0.309    3.582    4.722      0.007    0.005
# tau_pre                0.653   0.046    0.570    0.739      0.001    0.001
# posterior_rate_diff   14.682   5.159    4.901   23.911      0.113    0.080
#
#                      ess_bulk  ess_tail  r_hat
# r_post                 2148.0    2205.0    1.0
# r_pre                  3085.0    2544.0    1.0
# k_post                 1691.0    2041.0    1.0
# k_slow                 2234.0    2297.0    1.0
# tau_post_slow          2089.0    2168.0    1.0
# t_switch               2393.0    2311.0    1.0
# k_pre                  1586.0    1807.0    1.0
# tau_post_fast          1905.0    2254.0    1.0
# tau_pre                2694.0    2229.0    1.0
# posterior_rate_diff    2131.0    2143.0    1.0

# %%
az.plot_trace(idata,backend_kwargs={'layout': 'constrained'},
              var_names=var_names
              )
# Out:
# array([[<Axes: title={'center': 'r_post'}>,
#         <Axes: title={'center': 'r_post'}>],
#        [<Axes: title={'center': 'r_pre'}>,
#         <Axes: title={'center': 'r_pre'}>],
#        [<Axes: title={'center': 'k_post'}>,
#         <Axes: title={'center': 'k_post'}>],
#        [<Axes: title={'center': 'k_slow'}>,
#         <Axes: title={'center': 'k_slow'}>],
#        [<Axes: title={'center': 'tau_post_slow'}>,
#         <Axes: title={'center': 'tau_post_slow'}>],
#        [<Axes: title={'center': 't_switch'}>,
#         <Axes: title={'center': 't_switch'}>],
#        [<Axes: title={'center': 'k_pre'}>,
#         <Axes: title={'center': 'k_pre'}>],
#        [<Axes: title={'center': 'tau_post_fast'}>,
#         <Axes: title={'center': 'tau_post_fast'}>],
#        [<Axes: title={'center': 'tau_pre'}>,
#         <Axes: title={'center': 'tau_pre'}>],
#        [<Axes: title={'center': 'posterior_rate_diff'}>,
#         <Axes: title={'center': 'posterior_rate_diff'}>]], dtype=object)

# %%
az.plot_posterior(idata, var_names=var_names,textsize=7,hdi_prob=0.97)
plt.show()

# %% [markdown]
# ## Compute predictions over a set of new input points

# %%
X_test = np.linspace(-10,400,20000)

idata_predictions = compute_predictions_over_new_data(on_model,idata,X_test)
# Out:
# Sampling: [count_pred_new]
# [distfit] >INFO> Sampling: [count_pred_new]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:27&lt;00:00]
#     </div>

# %%
calculate_rate_percentages_of_peak(idata_predictions.predictions,X_test,cell_type='ON')
# Out:
# Summary (mean, median, 95% HDI):
#
#                           mean      sd  hdi_1.5%  hdi_98.5%  mcse_mean  \
# Time to rise to 10.0%   -1.679   0.082    -1.861     -1.513      0.001
# Time to fall to 10.0%  221.959  15.834   183.612    248.784      0.358
#
#                        mcse_sd  ess_bulk  ess_tail  r_hat
# Time to rise to 10.0%    0.001    3038.0    3062.0    1.0
# Time to fall to 10.0%    0.253    2058.0    2119.0    1.0
#
# Explicit numeric results:
# Rise to 0.1% - mean: -1.679, median: -1.677, 95% HDI: [-1.861, -1.513]
# Fall to 0.1% - mean: 221.959, median: 224.788, 95% HDI: [183.612, 248.784]
# Summary (mean, median, 95% HDI):
#
#                          mean     sd  hdi_1.5%  hdi_98.5%  mcse_mean  mcse_sd  \
# Time to rise to 50.0%  -0.628  0.028    -0.693     -0.570      0.000    0.000
# Time to fall to 50.0%  15.392  3.086     9.373     22.433      0.068    0.048
#
#                        ess_bulk  ess_tail  r_hat
# Time to rise to 50.0%    3311.0    3242.0    1.0
# Time to fall to 50.0%    1970.0    1749.0    1.0
#
# Explicit numeric results:
# Rise to 0.5% - mean: -0.628, median: -0.631, 95% HDI: [-0.693, -0.570]
# Fall to 0.5% - mean: 15.392, median: 15.104, 95% HDI: [9.373, 22.433]
# Summary (mean, median, 95% HDI):
#
#                         mean     sd  hdi_1.5%  hdi_98.5%  mcse_mean  mcse_sd  \
# Time to rise to 90.0% -0.244  0.037    -0.324     -0.180      0.001    0.001
# Time to fall to 90.0%  0.816  0.088     0.620      0.989      0.002    0.001
#
#                        ess_bulk  ess_tail  r_hat
# Time to rise to 90.0%    2415.0    2288.0    1.0
# Time to fall to 90.0%    1802.0    2164.0    1.0
#
# Explicit numeric results:
# Rise to 0.9% - mean: -0.244, median: -0.242, 95% HDI: [-0.324, -0.180]
# Fall to 0.9% - mean: 0.816, median: 0.804, 95% HDI: [0.620, 0.989]

# %%
# Extract posterior lambda and summarize
lambda_preds = idata_predictions.predictions['rate']
lambda_mean = lambda_preds.mean(("chain","draw"))
# lambda_mean

count_preds = idata_predictions.predictions['count_pred_new']
count_pred_mean = count_preds.mean(("chain","draw"))
count_pred_upper = count_preds.quantile(0.975,("chain","draw"))
count_pred_lower = count_preds.quantile(0.025,("chain","draw"))

# %%
preds_numpy = count_preds.to_numpy()
print(preds_numpy.shape)
preds_numpy = preds_numpy.T.reshape((X_test.shape[0],-1))
preds_numpy.shape
# Out:
# (4, 1000, 20000)
# (20000, 4000)

# %%
plot_predictions_paper(counts,X_test,count_pred_mean,lambda_preds,lambda_mean,preds_numpy, cell_name="ON",
                       filename="18_switching_model_ON_cells_double_exp_aggregated",
                   basePath=base_path,save=True)

# %% [markdown]
# ## Store the model predictions for important quantities

# %%
prediction_save_path: Path = Path("./models/on_models/18_double_exponential_aggregated_counts/ON_model_double_exp_mean_predictions")

data = {
    "counts":counts ,
    "X_test":X_test ,
    "count_pred_mean":count_pred_mean ,
    "lambda_preds":lambda_preds ,
    "lambda_mean":lambda_mean ,
    "preds_numpy":preds_numpy,
    "t_switch": idata.posterior['t_switch']

}

store_model_predictions(prediction_save_path,data)
