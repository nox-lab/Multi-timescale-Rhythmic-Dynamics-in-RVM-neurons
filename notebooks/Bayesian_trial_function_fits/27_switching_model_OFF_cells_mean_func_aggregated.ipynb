# %% [markdown]
# # OFF cell mean model

# %%
# Autoreloading of modules and files without restarting notebook.
# %reload_ext autoreload
# %autoreload 2

import os
import json
import arviz as az
import numpy as np
from pathlib import Path
from quantities import s
import matplotlib.pyplot as plt
from pymc import model_to_graphviz


from rvm_analysis.utils import combine_datasets_into_data_manager
from rvm_analysis.utils import import_on_off_trials, import_extra_cells
from rvm_analysis.trial_analysis_functions import create_trial_df
from rvm_analysis.bayesian_cell_models import store_model_predictions
from rvm_analysis.bayesian_cell_models import plot_prior_predictive_checks,calculate_rate_percentages_of_peak_OFF
from rvm_analysis.bayesian_cell_models import create_X_and_Y_training_data,build_mean_model
from rvm_analysis.bayesian_cell_models import sample_model,compute_and_save_log_likelihood,compute_predictions_over_new_data
from rvm_analysis.plotting import plot_predictions_paper
from rvm_analysis.data_loaders import read_dataset_by_protocol


#! Force the backend back to matplotlib inline (after importing viziphant).
# %matplotlib inline
print(plt.get_backend())
# Out:
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="c779ae4a-b70a-4e71-9907-8a88fc0caf2e" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"25832755-ff0f-40bc-ab8d-4384d911f4b3":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"4a9d13e570e94652b9a0edbb731587ce","client_comm_id":"eceb4afd00024d63a191a75812e49955"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"Any","default":"none"},{"name":"value","kind":"Any","default":null}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}]}};
#   var render_items = [{"docid":"25832755-ff0f-40bc-ab8d-4384d911f4b3","roots":{"p1002":"c779ae4a-b70a-4e71-9907-8a88fc0caf2e"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#
#
#   <img src='...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
# </div>
# module://matplotlib_inline.backend_inline

# %% [markdown]
# ## Import the trial data

# %%
def deprecated_spike_2_imports():
    """
    Data imports, deprecated in favour of importing directly from NWB.
    """
    dm1 = import_on_off_trials()
    dm2 = import_extra_cells()
    dm = combine_datasets_into_data_manager(dm1,dm2)
    return dm


dm = read_dataset_by_protocol(['evoked','ongoing','evoked/ongoing'])
# Out:
# Found 101 blocks from 101 NWB files.
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Mus03_CA3.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Mus23_CA2.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Mus25_CA2.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# LHb_Mus28_CA2.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Bic04_CA3.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Bic05_CA3.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Bic07_CA3.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Bic16_CA2.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Bic20_CA3.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Bic27_CA2.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Bic36_CA2.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Mus06_CA2.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Bic38_CA2.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Bic42_CA3.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Bic49_CA3.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Bic51_CA4.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Bic52_CA4.smrx
# ['paw_withdrawal', 'heat']
# ['flick', 'heat']
# DMHLido20_BL_cut.smrx
# ['paw_withdrawal', 'heat']
# ['flick', 'heat']
# DP_DTT_Bic02_BL_cut.smrx
# ['paw_withdrawal', 'heat']
# ['flick', 'heat']
# HDB_Bic06_BL_cut.smrx
# ['paw_withdrawal', 'heat']
# ['flick', 'heat']
# HDB_Bic11_BL_cut.smrx
# ['paw_withdrawal', 'heat']
# ['flick', 'heat']
# HDB_Mus20_BL_cut.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Mus07_CA2.smrx
# ['paw_withdrawal', 'heat']
# ['flick', 'heat']
# HDB_Mus22_BL_cut.smrx
# ['paw_withdrawal', 'heat']
# ['flick', 'heat']
# HDB_Mus38_BL_cut.smrx
# ['paw_withdrawal', 'heat']
# ['flick', 'heat']
# HDB_Mus55_BL_cut.smrx
# ['paw_withdrawal', 'heat']
# ['flick', 'heat']
# HDB_Mus60_BL_cut.smrx
# ['paw_withdrawal', 'heat']
# ['flick', 'heat']
# HDB_Mus65_BL_cut.smrx
# ['paw_withdrawal', 'heat']
# ['flick', 'heat']
# HDB_Mus67_BL_cut.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# HDB_Bic09_cut_truncated.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# HDB_Bic115_cut_truncated.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# HDB_Bic12_cut_truncated.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# HDB_Bic125_cut_truncated.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Mus09_CA2.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# HDB_Bic42_cut_truncated.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# HDB_Bic43_cut_truncated.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# HDB_Bic47_cut_truncated.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# HDB_Bic48_cut_truncated.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# HDB_Bic51_cut_truncated.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# HDB_Bic56_cut_truncated.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# HDB_Bic57_cut_truncated.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# HDB_Bic58_cut_truncated.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# HDB_Bic62_cut_truncated.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# HDB_Bic67_cut_truncated.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Mus13_CA2.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# HDB_Bic72_cut_truncated.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# HDB_Bic73_cut_truncated.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# HDB_Bic79_cut_truncated.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# HDB_Bic80_cut_truncated.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# Naive 4-16-24 a ON@2390_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# Naive 4-16-24 b ON@2765_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# Naive 4-16-24 c OFF&ON@2935_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# ZS Naive 4-17-24 a ON@1695_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# ZS Naive 4-18-24 #1 ON&OFF@2120_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# ZS Naive 4-22-24a OFF@2465_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# ZS Naive 4-22-24b OFF@2068_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# ZS Naive 4-23-24a ON@2249_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# ZS Naive 4-23-24b OFF&ON@3244_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# ZS Naive 4-24-24a OFF@1665_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Mus14_CA2.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# ZS Naive 4-25-24a ON@2646_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# ZS Naive 4-25-24b OFF@3009_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# ZS Naive 4-29-24a OFF@2839_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# ZS Naive 4-30-24a OFF@2789_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# ZS Naive 4-30-24b ON@2455_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# ZS Naive 5-1-24a OFF@2302_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# ZS Naive 5-1-24b OFF@2540_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# ZS Naive 5-1-24c ON@2934_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# ZS Naive 5-2-24a OFF@2030_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# ZS Naive 5-2-24b OFF@2632_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# CA_ongoing01a_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# CA_ongoing01b_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# CA_ongoing02a_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# CA_ongoing02b_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# CA_ongoing02c_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# CA_ongoing03a_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# CA_ongoing03b_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# CA_ongoing04a_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# CA_ongoing04b_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# CA_ongoing05a_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# CA_ongoing05b_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Mus15_CA2.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# CA_ongoing06a_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# CA_ongoing06b_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# CA_ongoing07a_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# CA_ongoing07b_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# CA_ongoing08a_cut_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# Neutral ongoing 7-17-24 @1165_Pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# Neutral ongoing 7-19-24@2583_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# Neutral ongoing 7-31-24@2940_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# Neutral ongoing 8-1-24@2827_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# Neutral ongoing 8-14-24@1505_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# Neutral ongoing 8-15-24@4020_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# Neutral Ongoing 8-29-24 @2950_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Mus16_CA2.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# Neutral ongoing 8-7-24 #1@2797_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# Neutral ongoing 8-7-24 #2@2984_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# Neutral ongoing 8-8-24@3195_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# Neutral ongoing 9-4-24 @2670_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat', 'pinch']
# ['EKG', 'flick', 'heat', 'keyboard']
# Neutral ongoing 9-5-24 neutral@2749_pared.smrx
# ['EKG', 'paw_withdrawal', 'heat']
# ['EKG', 'flick', 'heat']
# LHb_Mus22_CA2.smrx

# %%
base_path: Path = Path("./models/off_models/27_mean_func_aggregated_counts/")
model_name ="off_trial_model.nc"
full_path = base_path / model_name
parameter_dictionary = base_path / "param_dict.json"

with open(parameter_dictionary,"r") as f:
    p: dict = json.load(f)

p
# Out:
# {'POST_EVENT_PERIOD': 100,
#  'PRE_EVENT_PERIOD': -10,
#  'SKIP': 1,
#  'DRAWS': 1000,
#  'TUNE': 1000,
#  'BIN_SIZE': 0.05,
#  'PRIORS': {'SIGMA_BASE_RATE': 5}}

# %%
on_flick_list, on_flick_list_by_cell = dm.plot_spikes_around_event("flick",p["PRE_EVENT_PERIOD"] * s,p["POST_EVENT_PERIOD"] * s,
                                                                             cell_type='OFF',sorted_by=None,color_by_file=False,
                                                                             save=None,plot=False)
# Out:
# Next event [end,960.6372463999999 s] cuts off window
# Next event [end,960.6372463999999 s] cuts off window
# Next event [end,960.6323349999999 s] cuts off window
# Next event [end,965.3120307999999 s] cuts off window
# Next event [end,965.3120307999999 s] cuts off window
# Next event [end,967.7341075999999 s] cuts off window
# Next event [end,967.7341075999999 s] cuts off window
# Next event [end,961.8416963999999 s] cuts off window
# Next event [end,960.6701883999999 s] cuts off window
# Next event [end,960.8069171999999 s] cuts off window
# Next event [end,961.6389431999999 s] cuts off window
# Next event [end,961.6389431999999 s] cuts off window
# Next event [end,962.4861661999998 s] cuts off window
# Next event [end,962.4861661999998 s] cuts off window
# Next event [end,961.2888323999999 s] cuts off window
# Next event [end,961.2888323999999 s] cuts off window
# Next event [heat,306.67527279999996 s] cuts off window
# Next event [end,963.6889001999999 s] cuts off window
# Next event [end,963.6889001999999 s] cuts off window
# Next event [heat,194.62610959999998 s] cuts off window
# Next event [heat,194.62610959999998 s] cuts off window
# Next event [heat,194.62610959999998 s] cuts off window
# Next event [end,962.9015031999999 s] cuts off window
# Next event [end,960.8657915999999 s] cuts off window
# Next event [end,960.8657915999999 s] cuts off window
# Next event [end,3368.0 s] cuts off window
# Next event [end,962.4932797999999 s] cuts off window
# Next event [end,2557.0 s] cuts off window
# Next event [heat,2031.2359989999998 s] cuts off window
# Next event [end,2123.0 s] cuts off window
# Next event [end,2382.0 s] cuts off window
# Next event [end,2084.0 s] cuts off window
# Next event [heat,1970.1713641999997 s] cuts off window
# Next event [end,2052.0 s] cuts off window
# Next event [heat,2032.5114211999996 s] cuts off window
# Next event [end,2259.0 s] cuts off window
# Next event [heat,2032.5114211999996 s] cuts off window
# Next event [end,2259.0 s] cuts off window
# Next event [heat,2027.8147343999997 s] cuts off window
# Next event [end,2055.0 s] cuts off window
# Next event [end,961.5060883999998 s] cuts off window
# Next event [end,2022.0 s] cuts off window
# Next event [heat,1949.2471595999998 s] cuts off window
# Next event [end,1995.0 s] cuts off window
# Next event [end,2355.0 s] cuts off window
# Next event [end,960.6941603999999 s] cuts off window
# max possible flicks:  216
# Max possible heats:  216

# %%
df = create_trial_df(p["BIN_SIZE"] * s,on_flick_list_by_cell)
display(df)

# Plot the raw count data
plt.scatter(df['time'],df['count'])
plt.show()

counts = df.groupby('time',as_index=False)['count'].sum()
print(counts)
plt.show()
# Out:
#          index              animal  cell  trial   time  count
# 0            0  LHb_Mus03_CA3.smrx     0      0 -10.00      0
# 1            1  LHb_Mus03_CA3.smrx     0      0  -9.95      0
# 2            2  LHb_Mus03_CA3.smrx     0      0  -9.90      0
# 3            3  LHb_Mus03_CA3.smrx     0      0  -9.85      0
# 4            4  LHb_Mus03_CA3.smrx     0      0  -9.80      0
# ...        ...                 ...   ...    ...    ...    ...
# 373995  373995  LHb_Mus22_CA2.smrx    59      2  99.75      0
# 373996  373996  LHb_Mus22_CA2.smrx    59      2  99.80      0
# 373997  373997  LHb_Mus22_CA2.smrx    59      2  99.85      0
# 373998  373998  LHb_Mus22_CA2.smrx    59      2  99.90      0
# 373999  373999  LHb_Mus22_CA2.smrx    59      2  99.95      0
#
# [374000 rows x 6 columns]
#        time  count
# 0    -10.00     45
# 1     -9.95     57
# 2     -9.90     38
# 3     -9.85     50
# 4     -9.80     43
# ...     ...    ...
# 2195  99.75     35
# 2196  99.80     34
# 2197  99.85     28
# 2198  99.90     38
# 2199  99.95     34
#
# [2200 rows x 2 columns]

# %%
X_data,Y_data = create_X_and_Y_training_data(counts,skip=1,plot=True)

# %% [markdown]
# ## Define Our Model

# %%
off_model = build_mean_model(X_data,Y_data,p)

# %%
model_to_graphviz(off_model,save=os.path.join(base_path,"graph.png")) # .render('model')

# %%
X_test = np.linspace(-4,20,100)
plot_prior_predictive_checks(off_model,X_test,n_sample_paths=10)
# Out:
# Sampling: [base_rate]
# [distfit] >INFO> Sampling: [base_rate]

# %%
SAMPLE = False
idata = sample_model(off_model,X_data,full_path,p,sample=SAMPLE,chains=4)

# %%
var_names = ["base_rate"]

# %% [markdown]
# ## Compute the model log likelihood and save

# %%
COMPUTE_LL = True
loglik_save_path = base_path / "idata_with_log_liks.nc" 

compute_and_save_log_likelihood(off_model,idata,save_path=loglik_save_path,recompute=COMPUTE_LL)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:00&lt;00:00]
#     </div>
# Computed from 4000 posterior samples and 2200 observations log-likelihood matrix.
#
#          Estimate       SE
# elpd_loo -9237.17   122.21
# p_loo        2.90        -
# ------
#
# Pareto k diagnostic values:
#                          Count   Pct.
# (-Inf, 0.5]   (good)     2200  100.0%
#  (0.5, 0.7]   (ok)          0    0.0%
#    (0.7, 1]   (bad)         0    0.0%
#    (1, Inf)   (very bad)    0    0.0%

# %%
# Print a summary of the model parameters
display(az.summary(idata,var_names=var_names))
# Out:
#              mean    sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# base_rate  28.575  0.11  28.361   28.774      0.003    0.002    1795.0
#
#            ess_tail  r_hat
# base_rate    2734.0    1.0

# %%
# plot the traces of the model
az.plot_trace(idata,backend_kwargs={'layout': 'constrained'},
              var_names=var_names
              )
# Out:
# array([[<Axes: title={'center': 'base_rate'}>,
#         <Axes: title={'center': 'base_rate'}>]], dtype=object)

# %% [markdown]
# ## Compute predictions over a set of new input points

# %%
X_test = np.linspace(-10,100,2000)
idata_predictions = compute_predictions_over_new_data(off_model,idata,X_test)
# Out:
# Sampling: [count_pred_new]
# [distfit] >INFO> Sampling: [count_pred_new]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:01&lt;00:00]
#     </div>

# %%
# Extract posterior lambda and summarize
lambda_preds = idata_predictions.predictions['rate']
lambda_mean = lambda_preds.mean(("chain","draw"))
# lambda_mean

count_preds = idata_predictions.predictions['count_pred_new']
count_pred_mean = count_preds.mean(("chain","draw"))
count_pred_upper = count_preds.quantile(0.975,("chain","draw"))
count_pred_lower = count_preds.quantile(0.025,("chain","draw"))

# %%
preds_numpy = count_preds.to_numpy()
print(preds_numpy.shape)
preds_numpy = preds_numpy.T.reshape((2000,-1))
preds_numpy.shape
# Out:
# (4, 1000, 2000)
# (2000, 4000)

# %%
from rvm_analysis.plotting import plot_predictions_paper

plot_predictions_paper(counts,X_test,count_pred_mean,lambda_preds,lambda_mean,preds_numpy, cell_name="OFF",
                       filename="20_switching_model_OFF_cells_mean_func_aggregated",
                   basePath="./models/off_models/27_mean_func_aggregated_counts",save=True)
