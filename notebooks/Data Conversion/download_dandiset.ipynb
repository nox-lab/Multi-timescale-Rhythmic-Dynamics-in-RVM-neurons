# %%
from rvm_analysis.data_loaders import download_dandiset

# Example usage
download_dandiset(
    "001708",
    r"../../data/dandiset/"
)
# Out:
# Saved dandiset.yaml to C:\Users\carla\Documents\Cambridge\PhD\Scripts\Spike2_Data_Analysis\data\dandiset\dandiset.yaml
# ...
# sub-rat-1/sub-rat-1_ses-1.nwb: 100%|██████████| 490k/490k [00:00<00:00, 1.42MB/s]
# ...
# sub-rat-12/sub-rat-12_ses-1.nwb: 100%|██████████| 511k/511k [00:00<00:00, 1.37MB/s]
# ...
# sub-rat-10/sub-rat-10_ses-1.nwb: 100%|██████████| 553k/553k [00:00<00:00, 1.55MB/s]
# ...
# sub-rat-11/sub-rat-11_ses-1.nwb: 100%|██████████| 523k/523k [00:00<00:00, 1.43MB/s]
# ...
# sub-rat-13/sub-rat-13_ses-1.nwb: 100%|██████████| 624k/624k [00:00<00:00, 1.67MB/s]
# ...
# sub-rat-14/sub-rat-14_ses-1.nwb: 100%|██████████| 554k/554k [00:00<00:00, 1.50MB/s]
# ...
# sub-rat-18/sub-rat-18_ses-1.nwb: 100%|██████████| 582k/582k [00:00<00:00, 1.57MB/s]
# ...
# sub-rat-15/sub-rat-15_ses-1.nwb: 100%|██████████| 515k/515k [00:00<00:00, 1.41MB/s]
# ...
# sub-rat-16/sub-rat-16_ses-1.nwb: 100%|██████████| 545k/545k [00:00<00:00, 1.50MB/s]
# ...
# sub-rat-17/sub-rat-17_ses-1.nwb: 100%|██████████| 529k/529k [00:00<00:00, 1.31MB/s]
# ...
